# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.layers import Dense, Input, GlobalMaxPooling1D
from tensorflow.keras.layers import Conv1D, MaxPooling1D
from tensorflow.keras.models import Model

np.random.seed(123)
tf.random.set_seed(123)

# %%
from sklearn.metrics import mean_absolute_percentage_error

# %%
df = pd.read_csv('airline_passengers.csv', index_col='Month', parse_dates=True)

# %%
df['LogPassengers'] = np.log(df['Passengers'])

# %%
Ntest = 12
train = df.iloc[:-Ntest]
test = df.iloc[-Ntest:]

# %%
# boolean series to index df rows
train_idx = df.index <= train.index[-1] # indexes less than the last values of train
test_idx = df.index > train.index[-1] # indexes greater than the last value of train

# %%
df['DiffLogPassengers'] = df['LogPassengers'].diff()

# %%
# make supervised dataset

series = df['DiffLogPassengers'].dropna().to_numpy()

T = 10 # number of lags
X = []
Y = []
for t in range(len(series) - T):
    x = series[t:t+T]
    X.append(x)
    y = series[t+T]
    Y.append(y)

X = np.array(X).reshape(-1, T, 1)
Y = np.array(Y)
N = len(X)
print("X.shape", X.shape, "Y.shape", Y.shape)
# Out:
# X.shape (133, 10, 1) Y.shape (133,)

# %%
Xtrain, Ytrain = X[:-Ntest], Y[:-Ntest]
Xtest, Ytest = X[-Ntest:], Y[-Ntest:]

# %%
# CNN
i = Input(shape=(T,1))
x = Conv1D(16, 3, activation='relu')(i)
x = MaxPooling1D(2)(x)
x = Conv1D(32, 3, activation='relu')(x)
x = GlobalMaxPooling1D()(x)
x = Dense(1)(x)
model = Model(i,x)

# %%
model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 10, 1)]           0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 8, 16)             64
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 4, 16)             0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 2, 32)             1568
# _________________________________________________________________
# global_max_pooling1d (Global (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 33
# =================================================================
# Total params: 1,665
# Trainable params: 1,665
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    loss='mse',
    optimizer='adam'
)

# %%
r = model.fit(
    Xtrain,
    Ytrain,
    epochs=100,
    validation_data=(Xtest, Ytest)
)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0110 - val_loss: 0.0112
# Epoch 2/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0102 - val_loss: 0.0109
# Epoch 3/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0097 - val_loss: 0.0105
# Epoch 4/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0093 - val_loss: 0.0100
# Epoch 5/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0089 - val_loss: 0.0097
# Epoch 6/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0086 - val_loss: 0.0094
# Epoch 7/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0081 - val_loss: 0.0091
# Epoch 8/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0077 - val_loss: 0.0089
# Epoch 9/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0074 - val_loss: 0.0086
# Epoch 10/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0071 - val_loss: 0.0083
# Epoch 11/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0067 - val_loss: 0.0080
# Epoch 12/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0063 - val_loss: 0.0077
# Epoch 13/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0059 - val_loss: 0.0075
# Epoch 14/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0055 - val_loss: 0.0072
# Epoch 15/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0052 - val_loss: 0.0069
# Epoch 16/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0049 - val_loss: 0.0067
# Epoch 17/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0045 - val_loss: 0.0064
# Epoch 18/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0042 - val_loss: 0.0061
# Epoch 19/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0039 - val_loss: 0.0058
# Epoch 20/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0037 - val_loss: 0.0055
# Epoch 21/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0035 - val_loss: 0.0053
# Epoch 22/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0032 - val_loss: 0.0051
# Epoch 23/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0030 - val_loss: 0.0048
# Epoch 24/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0028 - val_loss: 0.0047
# Epoch 25/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0026 - val_loss: 0.0045
# Epoch 26/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0026 - val_loss: 0.0044
# Epoch 27/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0024 - val_loss: 0.0043
# Epoch 28/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0023 - val_loss: 0.0041
# Epoch 29/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0021 - val_loss: 0.0041
# Epoch 30/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0021 - val_loss: 0.0039
# Epoch 31/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0019 - val_loss: 0.0039
# Epoch 32/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0019 - val_loss: 0.0038
# Epoch 33/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0018 - val_loss: 0.0037
# Epoch 34/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0017 - val_loss: 0.0036
# Epoch 35/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0017 - val_loss: 0.0036
# Epoch 36/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0016 - val_loss: 0.0035
# Epoch 37/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0016 - val_loss: 0.0035
# Epoch 38/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0015 - val_loss: 0.0034
# Epoch 39/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0015 - val_loss: 0.0034
# Epoch 40/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0015 - val_loss: 0.0034
# Epoch 41/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0015 - val_loss: 0.0033
# Epoch 42/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 0.0033
# Epoch 43/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 0.0033
# Epoch 44/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0013 - val_loss: 0.0032
# Epoch 45/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0032
# Epoch 46/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0032
# Epoch 47/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0031
# Epoch 48/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0013 - val_loss: 0.0031
# Epoch 49/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0032
# Epoch 50/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0012 - val_loss: 0.0031
# Epoch 51/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0012 - val_loss: 0.0031
# Epoch 52/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0011 - val_loss: 0.0031
# Epoch 53/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0030
# Epoch 54/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0030
# Epoch 55/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0011 - val_loss: 0.0030
# Epoch 56/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0030
# Epoch 57/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0030
# Epoch 58/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0030
# Epoch 59/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0030
# Epoch 60/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0031
# Epoch 61/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0030
# Epoch 62/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0010 - val_loss: 0.0029
# Epoch 63/100
# 4/4 [==============================] - 0s 4ms/step - loss: 9.8286e-04 - val_loss: 0.0030
# Epoch 64/100
# 4/4 [==============================] - 0s 4ms/step - loss: 9.7109e-04 - val_loss: 0.0030
# Epoch 65/100
# 4/4 [==============================] - 0s 4ms/step - loss: 9.8364e-04 - val_loss: 0.0030
# Epoch 66/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0010 - val_loss: 0.0029
# Epoch 67/100
# 4/4 [==============================] - 0s 5ms/step - loss: 9.2903e-04 - val_loss: 0.0029
# Epoch 68/100
# 4/4 [==============================] - 0s 4ms/step - loss: 9.8393e-04 - val_loss: 0.0030
# Epoch 69/100
# 4/4 [==============================] - 0s 4ms/step - loss: 9.3747e-04 - val_loss: 0.0029
# Epoch 70/100
# 4/4 [==============================] - 0s 4ms/step - loss: 9.2056e-04 - val_loss: 0.0029
# Epoch 71/100
# 4/4 [==============================] - 0s 5ms/step - loss: 9.1395e-04 - val_loss: 0.0030
# Epoch 72/100
# 4/4 [==============================] - 0s 4ms/step - loss: 8.8943e-04 - val_loss: 0.0029
# Epoch 73/100
# 4/4 [==============================] - 0s 4ms/step - loss: 9.0885e-04 - val_loss: 0.0030
# Epoch 74/100
# 4/4 [==============================] - 0s 5ms/step - loss: 8.8141e-04 - val_loss: 0.0030
# Epoch 75/100
# 4/4 [==============================] - 0s 5ms/step - loss: 8.7253e-04 - val_loss: 0.0030
# Epoch 76/100
# 4/4 [==============================] - 0s 5ms/step - loss: 9.0621e-04 - val_loss: 0.0029
# Epoch 77/100
# 4/4 [==============================] - 0s 5ms/step - loss: 9.1504e-04 - val_loss: 0.0030
# Epoch 78/100
# 4/4 [==============================] - 0s 5ms/step - loss: 8.7686e-04 - val_loss: 0.0030
# Epoch 79/100
# 4/4 [==============================] - 0s 5ms/step - loss: 8.6102e-04 - val_loss: 0.0030
# Epoch 80/100
# 4/4 [==============================] - 0s 4ms/step - loss: 8.4794e-04 - val_loss: 0.0029
# Epoch 81/100
# 4/4 [==============================] - 0s 4ms/step - loss: 8.4163e-04 - val_loss: 0.0029
# Epoch 82/100
# 4/4 [==============================] - 0s 4ms/step - loss: 8.2429e-04 - val_loss: 0.0030
# Epoch 83/100
# 4/4 [==============================] - 0s 4ms/step - loss: 8.1641e-04 - val_loss: 0.0029
# Epoch 84/100
# 4/4 [==============================] - 0s 4ms/step - loss: 8.0725e-04 - val_loss: 0.0030
# Epoch 85/100
# 4/4 [==============================] - 0s 5ms/step - loss: 8.3932e-04 - val_loss: 0.0029
# Epoch 86/100
# 4/4 [==============================] - 0s 6ms/step - loss: 8.2935e-04 - val_loss: 0.0029
# Epoch 87/100
# 4/4 [==============================] - 0s 5ms/step - loss: 7.9069e-04 - val_loss: 0.0030
# Epoch 88/100
# 4/4 [==============================] - 0s 6ms/step - loss: 7.6655e-04 - val_loss: 0.0030
# Epoch 89/100
# 4/4 [==============================] - 0s 5ms/step - loss: 7.7030e-04 - val_loss: 0.0030
# Epoch 90/100
# 4/4 [==============================] - 0s 6ms/step - loss: 7.6146e-04 - val_loss: 0.0030
# Epoch 91/100
# 4/4 [==============================] - 0s 5ms/step - loss: 7.8350e-04 - val_loss: 0.0030
# Epoch 92/100
# 4/4 [==============================] - 0s 5ms/step - loss: 7.4793e-04 - val_loss: 0.0030
# Epoch 93/100
# 4/4 [==============================] - 0s 5ms/step - loss: 7.4933e-04 - val_loss: 0.0030
# Epoch 94/100
# 4/4 [==============================] - 0s 5ms/step - loss: 7.4428e-04 - val_loss: 0.0030
# Epoch 95/100
# 4/4 [==============================] - 0s 5ms/step - loss: 7.8135e-04 - val_loss: 0.0030
# Epoch 96/100
# 4/4 [==============================] - 0s 5ms/step - loss: 7.3726e-04 - val_loss: 0.0030
# Epoch 97/100
# 4/4 [==============================] - 0s 4ms/step - loss: 7.8024e-04 - val_loss: 0.0030
# Epoch 98/100
# 4/4 [==============================] - 0s 4ms/step - loss: 7.5045e-04 - val_loss: 0.0030
# Epoch 99/100
# 4/4 [==============================] - 0s 4ms/step - loss: 7.1236e-04 - val_loss: 0.0031
# Epoch 100/100
# 4/4 [==============================] - 0s 5ms/step - loss: 7.2679e-04 - val_loss: 0.0030

# %%
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='test loss')
plt.legend();

# %%
train_idx[:T+1] = False # first T+1 values are not predictable

# %%
Ptrain = model.predict(Xtrain).flatten() # turn to 1D array
Ptest = model.predict(Xtest).flatten()

# %%
# Store diff predictions
df.loc[train_idx, 'Diff CNN Train Prediction'] = Ptrain
df.loc[test_idx, 'Diff CNN Test Prediction'] = Ptest

# %%
cols = ['DiffLogPassengers',
        'Diff CNN Train Prediction',
        'Diff CNN Test Prediction']
df[cols].plot(figsize=(15,5));

# %%
# Needed to compute un-differenced predictions
df['ShiftLogPassengers'] = df['LogPassengers'].shift(1)
prev = df['ShiftLogPassengers']

# %%
# Last-known train value
last_train = train.iloc[-1]['LogPassengers']

# %%
# 1-step forecast
df.loc[train_idx, '1step_train'] = prev[train_idx] + Ptrain
df.loc[test_idx, '1step_test'] = prev[test_idx] + Ptest

# %%
# plot 1-step forecast
df[['LogPassengers', '1step_train', '1step_test']].plot(figsize=(15,5));

# %%
# multi-step forecast
multistep_predictions = []

# first test input
last_x = Xtest[0]

while len(multistep_predictions) < Ntest:
    p = model.predict(last_x.reshape(1, -1))[0]

    # update the predictions list
    multistep_predictions.append(p)

    # make the new input
    last_x = np.roll(last_x, -1)
    last_x[-1] = p

# %%
# save multistep forecast to dataframe
df.loc[test_idx, 'multistep'] = last_train + np.cumsum(multistep_predictions)

# %%
cols = ['LogPassengers', 'multistep', '1step_test']
df[cols].plot(figsize=(15,5));

# %%
# make multi-output supervised dataset
Tx = T # number of step in the input
Ty = Ntest # number of steps in the output
X = []
Y = []
for t in range(len(series) - Tx - Ty + 1):
    x = series[t:t+Tx]
    X.append(x)
    y = series[t+Tx:t+Tx+Ty]
    Y.append(y)

X = np.array(X).reshape(-1, Tx, 1)
Y = np.array(Y).reshape(-1, Ty)
N = len(X)
print("X.shape", X.shape, "Y.shape", Y.shape)
# Out:
# X.shape (122, 10, 1) Y.shape (122, 12)

# %%
Xtrain_m, Ytrain_m = X[:-1], Y[:-1]
Xtest_m, Ytest_m = X[-1:], Y[-1:]

# %%
# CNN
i = Input(shape=(Tx,1))
x = Conv1D(16, 3, activation='relu')(i)
x = MaxPooling1D(2)(x)
x = Conv1D(32, 3, activation='relu')(x)
x = GlobalMaxPooling1D()(x)
x = Dense(Ty)(x)
model = Model(i, x)

# %%
model.compile(
    loss='mse',
    optimizer='adam'
)

# %%
r = model.fit(
    Xtrain_m,
    Ytrain_m,
    epochs=200,
    validation_data=(Xtest_m, Ytest_m)
)
# Out:
# Epoch 1/200
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0122 - val_loss: 0.0110
# Epoch 2/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0114 - val_loss: 0.0115
# Epoch 3/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0110 - val_loss: 0.0116
# Epoch 4/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0107 - val_loss: 0.0113
# Epoch 5/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0105 - val_loss: 0.0108
# Epoch 6/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0102 - val_loss: 0.0103
# Epoch 7/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0100 - val_loss: 0.0099
# Epoch 8/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0098 - val_loss: 0.0096
# Epoch 9/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0096 - val_loss: 0.0094
# Epoch 10/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0093 - val_loss: 0.0092
# Epoch 11/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0091 - val_loss: 0.0091
# Epoch 12/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0089 - val_loss: 0.0088
# Epoch 13/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0086 - val_loss: 0.0085
# Epoch 14/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0084 - val_loss: 0.0083
# Epoch 15/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0081 - val_loss: 0.0080
# Epoch 16/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0079 - val_loss: 0.0078
# Epoch 17/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0076 - val_loss: 0.0075
# Epoch 18/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0074 - val_loss: 0.0074
# Epoch 19/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0071 - val_loss: 0.0072
# Epoch 20/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0069 - val_loss: 0.0070
# Epoch 21/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0067 - val_loss: 0.0067
# Epoch 22/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0065 - val_loss: 0.0066
# Epoch 23/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0063 - val_loss: 0.0065
# Epoch 24/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0061 - val_loss: 0.0062
# Epoch 25/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0059 - val_loss: 0.0059
# Epoch 26/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0058 - val_loss: 0.0060
# Epoch 27/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0056 - val_loss: 0.0058
# Epoch 28/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0054 - val_loss: 0.0056
# Epoch 29/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0053 - val_loss: 0.0056
# Epoch 30/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0051 - val_loss: 0.0054
# Epoch 31/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0050 - val_loss: 0.0053
# Epoch 32/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0048 - val_loss: 0.0051
# Epoch 33/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0047 - val_loss: 0.0051
# Epoch 34/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0046 - val_loss: 0.0049
# Epoch 35/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0044 - val_loss: 0.0049
# Epoch 36/200
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0043 - val_loss: 0.0048
# Epoch 37/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0042 - val_loss: 0.0049
# Epoch 38/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0041 - val_loss: 0.0047
# Epoch 39/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0040 - val_loss: 0.0045
# Epoch 40/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0039 - val_loss: 0.0044
# Epoch 41/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0038 - val_loss: 0.0043
# Epoch 42/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0037 - val_loss: 0.0045
# Epoch 43/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0036 - val_loss: 0.0044
# Epoch 44/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0035 - val_loss: 0.0043
# Epoch 45/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0035 - val_loss: 0.0044
# Epoch 46/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0034 - val_loss: 0.0041
# Epoch 47/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0033 - val_loss: 0.0041
# Epoch 48/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0032 - val_loss: 0.0041
# Epoch 49/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0031 - val_loss: 0.0041
# Epoch 50/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0031 - val_loss: 0.0040
# Epoch 51/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0030 - val_loss: 0.0040
# Epoch 52/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0029 - val_loss: 0.0038
# Epoch 53/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0029 - val_loss: 0.0038
# Epoch 54/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0028 - val_loss: 0.0038
# Epoch 55/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0028 - val_loss: 0.0040
# Epoch 56/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0027 - val_loss: 0.0040
# Epoch 57/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0027 - val_loss: 0.0038
# Epoch 58/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0026 - val_loss: 0.0038
# Epoch 59/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0026 - val_loss: 0.0038
# Epoch 60/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0025 - val_loss: 0.0038
# Epoch 61/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0025 - val_loss: 0.0036
# Epoch 62/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0025 - val_loss: 0.0038
# Epoch 63/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0024 - val_loss: 0.0039
# Epoch 64/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0024 - val_loss: 0.0037
# Epoch 65/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0024 - val_loss: 0.0038
# Epoch 66/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0023 - val_loss: 0.0037
# Epoch 67/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0023 - val_loss: 0.0036
# Epoch 68/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0023 - val_loss: 0.0037
# Epoch 69/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0023 - val_loss: 0.0038
# Epoch 70/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0022 - val_loss: 0.0036
# Epoch 71/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0022 - val_loss: 0.0036
# Epoch 72/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0022 - val_loss: 0.0038
# Epoch 73/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0022 - val_loss: 0.0039
# Epoch 74/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0021 - val_loss: 0.0038
# Epoch 75/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0021 - val_loss: 0.0038
# Epoch 76/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0021 - val_loss: 0.0037
# Epoch 77/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0021 - val_loss: 0.0036
# Epoch 78/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0020 - val_loss: 0.0039
# Epoch 79/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0020 - val_loss: 0.0037
# Epoch 80/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0020 - val_loss: 0.0037
# Epoch 81/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0020 - val_loss: 0.0039
# Epoch 82/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0020 - val_loss: 0.0036
# Epoch 83/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0020 - val_loss: 0.0037
# Epoch 84/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0019 - val_loss: 0.0038
# Epoch 85/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0019 - val_loss: 0.0037
# Epoch 86/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0019 - val_loss: 0.0037
# Epoch 87/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0019 - val_loss: 0.0039
# Epoch 88/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0019 - val_loss: 0.0039
# Epoch 89/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0019 - val_loss: 0.0038
# Epoch 90/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0019 - val_loss: 0.0037
# Epoch 91/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 0.0038
# Epoch 92/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0018 - val_loss: 0.0037
# Epoch 93/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0018 - val_loss: 0.0037
# Epoch 94/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0018 - val_loss: 0.0037
# Epoch 95/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0018 - val_loss: 0.0037
# Epoch 96/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0018 - val_loss: 0.0037
# Epoch 97/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0018 - val_loss: 0.0037
# Epoch 98/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0018 - val_loss: 0.0037
# Epoch 99/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0017 - val_loss: 0.0036
# Epoch 100/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0017 - val_loss: 0.0038
# Epoch 101/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0017 - val_loss: 0.0037
# Epoch 102/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0017 - val_loss: 0.0035
# Epoch 103/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0017 - val_loss: 0.0036
# Epoch 104/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0017 - val_loss: 0.0039
# Epoch 105/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0017 - val_loss: 0.0037
# Epoch 106/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0017 - val_loss: 0.0035
# Epoch 107/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0017 - val_loss: 0.0037
# Epoch 108/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0016 - val_loss: 0.0038
# Epoch 109/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 0.0038
# Epoch 110/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0016 - val_loss: 0.0036
# Epoch 111/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0016 - val_loss: 0.0035
# Epoch 112/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0016 - val_loss: 0.0038
# Epoch 113/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0016 - val_loss: 0.0036
# Epoch 114/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0036
# Epoch 115/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 0.0036
# Epoch 116/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0016 - val_loss: 0.0037
# Epoch 117/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0016 - val_loss: 0.0038
# Epoch 118/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 0.0036
# Epoch 119/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0016 - val_loss: 0.0036
# Epoch 120/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0015 - val_loss: 0.0036
# Epoch 121/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0015 - val_loss: 0.0036
# Epoch 122/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0015 - val_loss: 0.0038
# Epoch 123/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0015 - val_loss: 0.0035
# Epoch 124/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0015 - val_loss: 0.0035
# Epoch 125/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0015 - val_loss: 0.0039
# Epoch 126/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0015 - val_loss: 0.0035
# Epoch 127/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0015 - val_loss: 0.0035
# Epoch 128/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0015 - val_loss: 0.0036
# Epoch 129/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0015 - val_loss: 0.0037
# Epoch 130/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0015 - val_loss: 0.0036
# Epoch 131/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0015 - val_loss: 0.0034
# Epoch 132/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0015 - val_loss: 0.0036
# Epoch 133/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0015 - val_loss: 0.0035
# Epoch 134/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0015 - val_loss: 0.0036
# Epoch 135/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0035
# Epoch 136/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0035
# Epoch 137/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 0.0035
# Epoch 138/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 0.0035
# Epoch 139/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0035
# Epoch 140/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0036
# Epoch 141/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0035
# Epoch 142/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0034
# Epoch 143/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0036
# Epoch 144/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0034
# Epoch 145/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0035
# Epoch 146/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 0.0036
# Epoch 147/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 0.0036
# Epoch 148/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0035
# Epoch 149/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0032
# Epoch 150/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 0.0034
# Epoch 151/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0036
# Epoch 152/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0034
# Epoch 153/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0013 - val_loss: 0.0034
# Epoch 154/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0034
# Epoch 155/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0034
# Epoch 156/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0034
# Epoch 157/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0013 - val_loss: 0.0034
# Epoch 158/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0034
# Epoch 159/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0013 - val_loss: 0.0035
# Epoch 160/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0034
# Epoch 161/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0013 - val_loss: 0.0034
# Epoch 162/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0013 - val_loss: 0.0033
# Epoch 163/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0034
# Epoch 164/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0035
# Epoch 165/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0034
# Epoch 166/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0013 - val_loss: 0.0033
# Epoch 167/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0033
# Epoch 168/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0034
# Epoch 169/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0013 - val_loss: 0.0035
# Epoch 170/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0013 - val_loss: 0.0032
# Epoch 171/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0013 - val_loss: 0.0034
# Epoch 172/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0013 - val_loss: 0.0035
# Epoch 173/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0013 - val_loss: 0.0032
# Epoch 174/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0013 - val_loss: 0.0032
# Epoch 175/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0013 - val_loss: 0.0035
# Epoch 176/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0013 - val_loss: 0.0032
# Epoch 177/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0013 - val_loss: 0.0032
# Epoch 178/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0013 - val_loss: 0.0033
# Epoch 179/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0013 - val_loss: 0.0035
# Epoch 180/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0013 - val_loss: 0.0032
# Epoch 181/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0013 - val_loss: 0.0033
# Epoch 182/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0013 - val_loss: 0.0034
# Epoch 183/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0032
# Epoch 184/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0012 - val_loss: 0.0033
# Epoch 185/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0012 - val_loss: 0.0032
# Epoch 186/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0012 - val_loss: 0.0032
# Epoch 187/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0012 - val_loss: 0.0032
# Epoch 188/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0012 - val_loss: 0.0033
# Epoch 189/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0012 - val_loss: 0.0031
# Epoch 190/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0012 - val_loss: 0.0033
# Epoch 191/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 0.0034
# Epoch 192/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 0.0031
# Epoch 193/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0012 - val_loss: 0.0033
# Epoch 194/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 0.0033
# Epoch 195/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0012 - val_loss: 0.0031
# Epoch 196/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0012 - val_loss: 0.0033
# Epoch 197/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0012 - val_loss: 0.0033
# Epoch 198/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0012 - val_loss: 0.0032
# Epoch 199/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0012 - val_loss: 0.0034
# Epoch 200/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0012 - val_loss: 0.0031

# %%
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='test loss')
plt.legend();

# %%
Ptrain = model.predict(Xtrain_m)
Ptest = model.predict(Xtest_m)

# %%
Ptrain.shape, Ptest.shape
# Out:
# ((121, 12), (1, 12))

# %%
Ptrain = Ptrain[:,0]
Ptest = Ptest[0]

# %%
df.loc[test_idx, 'Diff Multi-Output Test Prediction'] = Ptest
cols = ['DiffLogPassengers', 'Diff Multi-Output Test Prediction']
df[cols].plot(figsize=(15,5));

# %%
# save multi-output forecast to dataframe
df.loc[test_idx, 'multioutput'] = last_train + \
    np.cumsum(Ptest)

# %%
# plot all forecasts
cols = ['LogPassengers', 'multistep', '1step_test', 'multioutput']
df[cols].plot(figsize=(15,5));

# %%
# MAPE
test_log_loss = df.iloc[-Ntest:]['LogPassengers']
mape1 = mean_absolute_percentage_error(test_log_loss, df.loc[test_idx, 'multistep'])
print("multi-step MAPE:", mape1)

mape2 = mean_absolute_percentage_error(test_log_loss, df.loc[test_idx, 'multioutput'])
print("multi-output MAPE:", mape2)
# Out:
# multi-step MAPE: 0.003642729631224577
# multi-output MAPE: 0.007155414694696227

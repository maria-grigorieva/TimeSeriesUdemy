# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.layers import Dense, Input, GlobalMaxPooling1D
from tensorflow.keras.layers import Conv1D, MaxPooling1D
from tensorflow.keras.models import Model
np.random.seed(123)
tf.random.set_seed(123)

# %%
from sklearn.metrics import mean_absolute_percentage_error

# %%
df = pd.read_csv('aglt2.csv', index_col='datetime', parse_dates=True)

# %%
df.head()
# Out:
#                      queue  queue_utilization  queue_fullness  \
# datetime
# 2022-05-16 01:00:00  AGLT2             0.0829          1.1250
# 2022-05-16 02:00:00  AGLT2             0.3091          2.4286
# 2022-05-16 03:00:00  AGLT2             0.8750          1.3125
# 2022-05-16 04:00:00  AGLT2             1.1408          1.3729
# 2022-05-16 05:00:00  AGLT2             0.9855          1.0000
#
#                      queue_efficiency
# datetime
# 2022-05-16 01:00:00            1.0000
# 2022-05-16 02:00:00            1.0000
# 2022-05-16 03:00:00            0.9792
# 2022-05-16 04:00:00            0.9437
# 2022-05-16 05:00:00            0.1739

# %%
df.shape
# Out:
# (3856, 4)

# %%
df.index = pd.to_datetime(df.index, format='YYYY-MM-DD HH:MI:SS')

# %%
df = df[['queue_fullness']].iloc[3500:3800,:].sort_index()

# %%
df['queue_fullness'] = df['queue_fullness'].apply(lambda x: x if x > 0.0000 else 0.0001)

# %%
df = df[~df.index.duplicated()]

# %%
df = df.asfreq('1H')

# %%
df = df.fillna(0.0001)

# %%
df['LogFullness'] = np.log(df['queue_fullness'])

# %%
df
# Out:
#                      queue_fullness  LogFullness
# datetime
# 2022-05-01 01:00:00          8.0000     2.079442
# 2022-05-01 02:00:00          0.0001    -9.210340
# 2022-05-01 03:00:00          1.1250     0.117783
# 2022-05-01 04:00:00          1.1316     0.123633
# 2022-05-01 05:00:00          1.2742     0.242319
# ...                             ...          ...
# 2022-05-13 12:00:00          5.8333     1.763583
# 2022-05-13 13:00:00         22.0000     3.091042
# 2022-05-13 14:00:00         28.9000     3.363842
# 2022-05-13 15:00:00         41.7143     3.730844
# 2022-05-13 16:00:00          1.3573     0.305497
#
# [304 rows x 2 columns]

# %%
df.plot();

# %%
Ntest = 6
train = df.iloc[:-Ntest]
test = df.iloc[-Ntest:]

# %%
# boolean series to index df rows
train_idx = df.index <= train.index[-1] # indexes less than the last values of train
test_idx = df.index > train.index[-1] # indexes greater than the last value of train

# %%
df['DiffLogFullness'] = df['LogFullness'].diff()

# %%
df['DiffLogFullness'].plot();

# %%
df.shape
# Out:
# (304, 3)

# %%
# make supervised dataset

series = df['DiffLogFullness'].dropna().to_numpy()

T = 10 # number of lags
X = []
Y = []
for t in range(len(series) - T):
    x = series[t:t+T]
    X.append(x)
    y = series[t+T]
    Y.append(y)

X = np.array(X).reshape(-1, T)
Y = np.array(Y)
N = len(X)
print("X.shape", X.shape, "Y.shape", Y.shape)
# Out:
# X.shape (293, 10) Y.shape (293,)

# %%
Xtrain, Ytrain = X[:-Ntest], Y[:-Ntest]
Xtest, Ytest = X[-Ntest:], Y[-Ntest:]

# %%
# CNN
i = Input(shape=(T,1))
x = Conv1D(16, 3, activation='relu')(i)
x = MaxPooling1D(2)(x)
x = Conv1D(32, 3, activation='relu')(x)
x = GlobalMaxPooling1D()(x)
x = Dense(1)(x)
model = Model(i,x)

# %%
tf.keras.utils.plot_model(model)

# %%
model.compile(
    loss='mse',
    optimizer='adam',
    metrics='mae'
)

# %%
r = model.fit(
    Xtrain,
    Ytrain,
    epochs=100,
    validation_data=(Xtest, Ytest)
)
# Out:
# Epoch 1/100
# 9/9 [==============================] - 0s 13ms/step - loss: 2.7226 - mae: 0.8520 - val_loss: 2.5583 - val_mae: 1.1692
# Epoch 2/100
# 9/9 [==============================] - 0s 2ms/step - loss: 2.6705 - mae: 0.8377 - val_loss: 2.5637 - val_mae: 1.1915
# Epoch 3/100
# 9/9 [==============================] - 0s 3ms/step - loss: 2.6098 - mae: 0.8221 - val_loss: 2.4492 - val_mae: 1.1700
# Epoch 4/100
# 9/9 [==============================] - 0s 3ms/step - loss: 2.5746 - mae: 0.8136 - val_loss: 2.4037 - val_mae: 1.1715
# Epoch 5/100
# 9/9 [==============================] - 0s 3ms/step - loss: 2.5473 - mae: 0.8084 - val_loss: 2.3975 - val_mae: 1.1752
# Epoch 6/100
# 9/9 [==============================] - 0s 2ms/step - loss: 2.5183 - mae: 0.8015 - val_loss: 2.3882 - val_mae: 1.1836
# Epoch 7/100
# 9/9 [==============================] - 0s 3ms/step - loss: 2.4912 - mae: 0.7958 - val_loss: 2.3386 - val_mae: 1.1700
# Epoch 8/100
# ...

# %%
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='test loss')
plt.legend();

# %%
train_idx[:T+1] = False # first T+1 values are not predictable

# %%
Ptrain = model.predict(Xtrain).flatten() # turn to 1D array
Ptest = model.predict(Xtest).flatten()

# %%
# Store diff predictions
df.loc[train_idx, 'Diff ANN Train Prediction'] = Ptrain
df.loc[test_idx, 'Diff ANN Test Prediction'] = Ptest

# %%
cols = ['DiffLogFullness',
        'Diff ANN Train Prediction',
        'Diff ANN Test Prediction']
df[cols].tail(50).plot(figsize=(15,5));

# %%
# Needed to compute un-differenced predictions
df['DiffLogFullness'] = df['LogFullness'].shift(1)
prev = df['DiffLogFullness']

# %%
# Last-known train value
last_train = train.iloc[-1]['LogFullness']

# %%
# 1-step forecast
df.loc[train_idx, '1step_train'] = prev[train_idx] + Ptrain
df.loc[test_idx, '1step_test'] = prev[test_idx] + Ptest

# %%
# plot 1-step forecast
df[['LogFullness', '1step_train', '1step_test']].tail(50).plot(figsize=(15,5));

# %%
# multi-step forecast
multistep_predictions = []

# first test input
last_x = Xtest[0]

while len(multistep_predictions) < Ntest:
    p = model.predict(last_x.reshape(1,-1))[0]

    # update the predictions list
    multistep_predictions.append(p)

    # make the new input
    last_x = np.roll(last_x, -1)
    last_x[-1] = p

# %%
# save multistep forecast to dataframe
df.loc[test_idx, 'multistep'] = last_train + np.cumsum(multistep_predictions)

# %%
cols = ['LogFullness', 'multistep', '1step_test']
df[cols].tail(50).plot(figsize=(15,5));

# %%
# make multi-output supervised dataset
Tx = T # number of step in the input
Ty = Ntest # number of steps in the output
X = []
Y = []
for t in range(len(series) - Tx - Ty + 1):
    x = series[t:t+Tx]
    X.append(x)
    y = series[t+Tx:t+Tx+Ty]
    Y.append(y)

X = np.array(X).reshape(-1, Tx)
Y = np.array(Y).reshape(-1, Ty)
N = len(X)
print("X.shape", X.shape, "Y.shape", Y.shape)
# Out:
# X.shape (288, 10) Y.shape (288, 6)

# %%
Xtrain_m, Ytrain_m = X[:-1], Y[:-1]
Xtest_m, Ytest_m = X[-1:], Y[-1:]

# %%
# CNN
i = Input(shape=(Tx,1))
x = Conv1D(16, 3, activation='relu')(i)
x = MaxPooling1D(2)(x)
x = Conv1D(32, 3, activation='relu')(x)
x = GlobalMaxPooling1D()(x)
x = Dense(Ty)(x)
model = Model(i, x)

# %%
model.compile(
    loss='mse',
    optimizer='adam'
)

# %%
r = model.fit(
    Xtrain_m,
    Ytrain_m,
    epochs=100,
    validation_data=(Xtest_m, Ytest_m)
)
# Out:
# Epoch 1/100
# 9/9 [==============================] - 0s 12ms/step - loss: 3.1646 - val_loss: 3.6151
# Epoch 2/100
# 9/9 [==============================] - 0s 2ms/step - loss: 2.8773 - val_loss: 3.1964
# Epoch 3/100
# 9/9 [==============================] - 0s 3ms/step - loss: 2.7860 - val_loss: 3.0118
# Epoch 4/100
# 9/9 [==============================] - 0s 2ms/step - loss: 2.7479 - val_loss: 3.0145
# Epoch 5/100
# 9/9 [==============================] - 0s 3ms/step - loss: 2.7283 - val_loss: 3.0641
# Epoch 6/100
# 9/9 [==============================] - 0s 3ms/step - loss: 2.7110 - val_loss: 3.0715
# Epoch 7/100
# 9/9 [==============================] - 0s 3ms/step - loss: 2.6969 - val_loss: 3.0859
# Epoch 8/100
# 9/9 [==============================] - 0s 3ms/step - loss: 2.6861 - val_loss: 3.0535
# Epoch 9/100
# 9/9 [==============================] - 0s 3ms/step - loss: 2.6764 - val_loss: 3.0739
# Epoch 10/100
# ...

# %%
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='test loss')
plt.legend();

# %%
Ptrain = model.predict(Xtrain_m)
Ptest = model.predict(Xtest_m)

# %%
Ptrain.shape, Ptest.shape
# Out:
# ((287, 6), (1, 6))

# %%
Ptrain = Ptrain[:,0]
Ptest = Ptest[0]

# %%
# save multi-output forecast to dataframe
df.loc[test_idx, 'multioutput'] = last_train + np.cumsum(Ptest)

# %%
# plot all forecasts
cols = ['LogFullness','multistep','1step_test','multioutput']
df[cols].tail(100).plot(figsize=(15,5));

# %%
# MAPE
test_log_loss = df.iloc[-Ntest:]['LogFullness']
mape1 = mean_absolute_percentage_error(test_log_loss, df.loc[test_idx, 'multistep'])
print("multi-step MAPE:", mape1)

mape2 = mean_absolute_percentage_error(test_log_loss, df.loc[test_idx, 'multioutput'])
print("multi-output MAPE:", mape2)
# Out:
# multi-step MAPE: 0.54757063888477
# multi-output MAPE: 1.9069994441866143
